# %%
import sys
sys.path.append("..")

from export_importable import export_model

export_model(
    weights=R"\\dl-trainer-4\D\Local\Yolo\Yv7\yolov7\runs\train\Therm20251104_pts04_try4\weights\last.pt",
    img_size=640,
    batch_size=1,
    device="0",
    onnx_only=True,
    grid=True,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 import sys
#       2 sys.path.append("..")
# ----> 4 from export_importable import export_model
#       6 export_model(
#       7     weights=R"\\dl-trainer-4\D\Local\Yolo\Yv7\yolov7\runs\train\Therm20251104_pts04_try4\weights\last.pt",
#       8     img_size=640,
#    (...)     12     grid=True,
#      13 )
#
# File d:\Local\Yolo\Yv7\yolov7\tools\..\export_importable.py:9
#       5 from types import SimpleNamespace
#       7 sys.path.append('./')  # to run '$ python *.py' files in subdirectories
# ----> 9 import torch
#      10 import torch.nn as nn
#      12 import models
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\__init__.py:2264
#    2260 sys.modules.setdefault(f"{__name__}.classes", classes)
#    2262 # quantization depends on torch.fx and torch.ops
#    2263 # Import quantization
# -> 2264 from torch import quantization as quantization  # usort: skip
#    2266 # Import the quasi random sampler
#    2267 from torch import quasirandom as quasirandom  # usort: skip
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\quantization\__init__.py:6
#       4 from .fuser_method_mappings import *  # noqa: F403
#       5 from .observer import *  # noqa: F403
# ----> 6 from .qconfig import *  # noqa: F403
#       7 from .quant_type import *  # noqa: F403
#       8 from .quantization_mappings import *  # noqa: F403
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\quantization\qconfig.py:9
#       1 # flake8: noqa: F401
#       2 r"""
#       3 This file is in the process of migration to `torch/ao/quantization`, and
#       4 is kept here for compatibility while the migration process is ongoing.
#    (...)      7 here.
#       8 """
# ----> 9 from torch.ao.quantization.qconfig import (
#      10     _add_module_to_qconfig_obs_ctr,
#      11     _assert_valid_qconfig,
#      12     default_activation_only_qconfig,
#      13     default_debug_qconfig,
#      14     default_dynamic_qconfig,
#      15     default_per_channel_qconfig,
#      16     default_qat_qconfig,
#      17     default_qat_qconfig_v2,
#      18     default_qconfig,
#      19     default_weight_only_qconfig,
#      20     float16_dynamic_qconfig,
#      21     float16_static_qconfig,
#      22     float_qparams_weight_only_qconfig,
#      23     get_default_qat_qconfig,
#      24     get_default_qconfig,
#      25     per_channel_dynamic_qconfig,
#      26     QConfig,
#      27     qconfig_equals,
#      28     QConfigAny,
#      29     QConfigDynamic,
#      30 )
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\ao\quantization\__init__.py:12
#      10 from .fuser_method_mappings import *  # noqa: F403
#      11 from .observer import *  # noqa: F403
# ---> 12 from .pt2e._numeric_debugger import (  # noqa: F401
#      13     compare_results,
#      14     CUSTOM_KEY,
#      15     extract_results_from_loggers,
#      16     generate_numeric_debug_handle,
#      17     NUMERIC_DEBUG_HANDLE_KEY,
#      18     prepare_for_propagation_comparison,
#      19 )
#      20 from .pt2e.export_utils import (
#      21     _allow_exported_model_train_eval as allow_exported_model_train_eval,
#      22     _move_exported_model_to_eval as move_exported_model_to_eval,
#      23     _move_exported_model_to_train as move_exported_model_to_train,
#      24 )
#      25 from .qconfig import *  # noqa: F403
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\ao\quantization\pt2e\_numeric_debugger.py:9
#       7 import torch
#       8 from torch.ao.ns.fx.utils import compute_sqnr
# ----> 9 from torch.ao.quantization.pt2e.graph_utils import bfs_trace_with_node_process
#      10 from torch.export import ExportedProgram
#      11 from torch.fx import GraphModule, Node
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\ao\quantization\pt2e\graph_utils.py:9
#       6 from typing import Any, Callable, Optional, Union
#       8 import torch
# ----> 9 from torch.export import ExportedProgram
#      10 from torch.fx import Node
#      11 from torch.fx.passes.utils.source_matcher_utils import (
#      12     check_subgraphs_connected,
#      13     get_source_partitions,
#      14     SourcePartition,
#      15 )
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\export\__init__.py:17
#      15 import torch.utils._pytree as pytree
#      16 from torch.fx._compatibility import compatibility
# ---> 17 from torch.fx.passes.infra.pass_base import PassResult
#      18 from torch.fx.passes.infra.pass_manager import PassManager
#      19 from torch.types import FileLike
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\__init__.py:1
# ----> 1 from . import (
#       2     graph_drawer,
#       3     graph_manipulation,
#       4     net_min_base,
#       5     operator_support,
#       6     param_fetch,
#       7     reinplace,
#       8     runtime_assert,
#       9     shape_prop,
#      10     split_module,
#      11     split_utils,
#      12     splitter_base,
#      13     tools_common,
#      14 )
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\net_min_base.py:12
#       9 from torch.fx.node import map_arg
#      11 from .shape_prop import ShapeProp
# ---> 12 from .split_utils import split_by_tags
#      13 from .tools_common import (
#      14     CALLABLE_NODE_OPS,
#      15     FxNetAccFusionsFinder,
#    (...)     20     Tensors,
#      21 )
#      24 __all__ = [
#      25     "FxNetMinimizerBadModuleError",
#      26     "FxNetMinimizerRunFuncError",
#      27     "FxNetMinimizerResultMismatchError",
#      28 ]
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\split_utils.py:11
#       8 from torch.fx.graph import map_arg
#       9 from torch.fx.passes.utils import HolderModule, lift_subgraph_as_module
# ---> 11 from .tools_common import NodeList
#      14 __all__ = ["getattr_recursive", "setattr_recursive", "Component", "split_by_tags"]
#      17 @compatibility(is_backward_compatible=False)
#      18 def getattr_recursive(obj, name):
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\tools_common.py:24
#      22 Tensors = Union[tuple[torch.Tensor], list[torch.Tensor]]
#      23 TensorOrTensors = Union[torch.Tensor, Tensors]
# ---> 24 NodeList = list[torch.fx.Node]
#      25 NodeSet = set[torch.fx.Node]
#      26 Names = list[str]
#
# AttributeError: partially initialized module 'torch' from 'd:\Local\Envs\ul5\Lib\site-packages\torch\__init__.py' has no attribute 'fx' (most likely due to a circular import)

# %%
import sys
sys.path.append("..")  # so Python can find the script

from export_importable_onnx_only import export_model

export_model(
    weights=R"\\dl-trainer-4\D\Local\Yolo\Yv7\yolov7\runs\train\Therm20251104_pts04_try4\weights\last.pt",
    img_size=640,
    batch_size=1,
    device="0",
    grid=True,        # or False, depending on what you want
    simplify=True,   # optional
    include_nms=False,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 import sys
#       2 sys.path.append("..")  # so Python can find the script
# ----> 4 from export_importable_onnx_only import export_model
#       6 export_model(
#       7     weights=R"\\dl-trainer-4\D\Local\Yolo\Yv7\yolov7\runs\train\Therm20251104_pts04_try4\weights\last.pt",
#       8     img_size=640,
#    (...)     13     include_nms=False,
#      14 )
#
# File d:\Local\Yolo\Yv7\yolov7\tools\..\export_importable_onnx_only.py:9
#       5 from types import SimpleNamespace
#       7 sys.path.append("./")  # to run '$ python *.py' files in subdirectories
# ----> 9 import torch
#      10 import torch.nn as nn
#      12 import models
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\__init__.py:2264
#    2260 sys.modules.setdefault(f"{__name__}.classes", classes)
#    2262 # quantization depends on torch.fx and torch.ops
#    2263 # Import quantization
# -> 2264 from torch import quantization as quantization  # usort: skip
#    2266 # Import the quasi random sampler
#    2267 from torch import quasirandom as quasirandom  # usort: skip
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\quantization\__init__.py:6
#       4 from .fuser_method_mappings import *  # noqa: F403
#       5 from .observer import *  # noqa: F403
# ----> 6 from .qconfig import *  # noqa: F403
#       7 from .quant_type import *  # noqa: F403
#       8 from .quantization_mappings import *  # noqa: F403
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\quantization\qconfig.py:9
#       1 # flake8: noqa: F401
#       2 r"""
#       3 This file is in the process of migration to `torch/ao/quantization`, and
#       4 is kept here for compatibility while the migration process is ongoing.
#    (...)      7 here.
#       8 """
# ----> 9 from torch.ao.quantization.qconfig import (
#      10     _add_module_to_qconfig_obs_ctr,
#      11     _assert_valid_qconfig,
#      12     default_activation_only_qconfig,
#      13     default_debug_qconfig,
#      14     default_dynamic_qconfig,
#      15     default_per_channel_qconfig,
#      16     default_qat_qconfig,
#      17     default_qat_qconfig_v2,
#      18     default_qconfig,
#      19     default_weight_only_qconfig,
#      20     float16_dynamic_qconfig,
#      21     float16_static_qconfig,
#      22     float_qparams_weight_only_qconfig,
#      23     get_default_qat_qconfig,
#      24     get_default_qconfig,
#      25     per_channel_dynamic_qconfig,
#      26     QConfig,
#      27     qconfig_equals,
#      28     QConfigAny,
#      29     QConfigDynamic,
#      30 )
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\ao\quantization\__init__.py:12
#      10 from .fuser_method_mappings import *  # noqa: F403
#      11 from .observer import *  # noqa: F403
# ---> 12 from .pt2e._numeric_debugger import (  # noqa: F401
#      13     compare_results,
#      14     CUSTOM_KEY,
#      15     extract_results_from_loggers,
#      16     generate_numeric_debug_handle,
#      17     NUMERIC_DEBUG_HANDLE_KEY,
#      18     prepare_for_propagation_comparison,
#      19 )
#      20 from .pt2e.export_utils import (
#      21     _allow_exported_model_train_eval as allow_exported_model_train_eval,
#      22     _move_exported_model_to_eval as move_exported_model_to_eval,
#      23     _move_exported_model_to_train as move_exported_model_to_train,
#      24 )
#      25 from .qconfig import *  # noqa: F403
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\ao\quantization\pt2e\_numeric_debugger.py:9
#       7 import torch
#       8 from torch.ao.ns.fx.utils import compute_sqnr
# ----> 9 from torch.ao.quantization.pt2e.graph_utils import bfs_trace_with_node_process
#      10 from torch.export import ExportedProgram
#      11 from torch.fx import GraphModule, Node
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\ao\quantization\pt2e\graph_utils.py:9
#       6 from typing import Any, Callable, Optional, Union
#       8 import torch
# ----> 9 from torch.export import ExportedProgram
#      10 from torch.fx import Node
#      11 from torch.fx.passes.utils.source_matcher_utils import (
#      12     check_subgraphs_connected,
#      13     get_source_partitions,
#      14     SourcePartition,
#      15 )
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\export\__init__.py:17
#      15 import torch.utils._pytree as pytree
#      16 from torch.fx._compatibility import compatibility
# ---> 17 from torch.fx.passes.infra.pass_base import PassResult
#      18 from torch.fx.passes.infra.pass_manager import PassManager
#      19 from torch.types import FileLike
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\__init__.py:1
# ----> 1 from . import (
#       2     graph_drawer,
#       3     graph_manipulation,
#       4     net_min_base,
#       5     operator_support,
#       6     param_fetch,
#       7     reinplace,
#       8     runtime_assert,
#       9     shape_prop,
#      10     split_module,
#      11     split_utils,
#      12     splitter_base,
#      13     tools_common,
#      14 )
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\net_min_base.py:12
#       9 from torch.fx.node import map_arg
#      11 from .shape_prop import ShapeProp
# ---> 12 from .split_utils import split_by_tags
#      13 from .tools_common import (
#      14     CALLABLE_NODE_OPS,
#      15     FxNetAccFusionsFinder,
#    (...)     20     Tensors,
#      21 )
#      24 __all__ = [
#      25     "FxNetMinimizerBadModuleError",
#      26     "FxNetMinimizerRunFuncError",
#      27     "FxNetMinimizerResultMismatchError",
#      28 ]
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\split_utils.py:11
#       8 from torch.fx.graph import map_arg
#       9 from torch.fx.passes.utils import HolderModule, lift_subgraph_as_module
# ---> 11 from .tools_common import NodeList
#      14 __all__ = ["getattr_recursive", "setattr_recursive", "Component", "split_by_tags"]
#      17 @compatibility(is_backward_compatible=False)
#      18 def getattr_recursive(obj, name):
#
# File d:\Local\Envs\ul5\Lib\site-packages\torch\fx\passes\tools_common.py:24
#      22 Tensors = Union[tuple[torch.Tensor], list[torch.Tensor]]
#      23 TensorOrTensors = Union[torch.Tensor, Tensors]
# ---> 24 NodeList = list[torch.fx.Node]
#      25 NodeSet = set[torch.fx.Node]
#      26 Names = list[str]
#
# AttributeError: partially initialized module 'torch' from 'd:\Local\Envs\ul5\Lib\site-packages\torch\__init__.py' has no attribute 'fx' (most likely due to a circular import)
